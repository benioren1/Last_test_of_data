# %%
from data_base.db_connection.db import engine
import pandas as pd


sql_query = "SELECT * FROM events"
df = pd.read_sql(sql_query, con=engine)

# %%
df;
# Out:
#         id  year  month   day summary                               gname  \
# 0        1  1970    7.0   2.0    None                              MANO-D
# 1        2  1970    NaN   NaN    None  23rd of September Communist League
# 2        3  1970    1.0   NaN    None                             Unknown
# 3        4  1970    1.0   NaN    None                             Unknown
# 4        5  1970    1.0   NaN    None                             Unknown
# ...    ...   ...    ...   ...     ...                                 ...
# 4140  4141  1976    9.0  12.0    None                             Unknown
# 4141  4142  1976    9.0  12.0    None                             Unknown
# 4142  4143  1976    9.0  13.0    None              Montoneros (Argentina)
# 4143  4144  1976    9.0  13.0    None              Montoneros (Argentina)
# 4144  4145  1976    9.0  15.0    None              Montoneros (Argentina)
#
#       killed  wounded  nperps  location_id  types_id
# ...

# %%
df.dtypes
# Out:
# id               int64
# year             int64
# month          float64
# day            float64
# summary         object
# gname           object
# killed         float64
# wounded        float64
# nperps         float64
# location_id      int64
# types_id         int64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 38
#      36 # לדוגמה, הצגת הגרף עבור שנה מסוימת
#      37 year_to_display = 1970  # שנה שאתה רוצה לבדוק
# ---> 38 plot_events_by_year(year_to_display)
#
# Cell In[8], line 33, in plot_events_by_year(year)
#      31 plt.xlabel('Month')
#      32 plt.ylabel('Number of Events')
# ---> 33 plt.xticks(df['Month'])  # הצגת חודשים על ציר ה-X
#      34 plt.show()
#
# File ~\PycharmProjects\Last_test_of_data\.venv\Lib\site-packages\matplotlib\pyplot.py:2241, in xticks(ticks, labels, minor, **kwargs)
#    2239 labels_out: list[Text] = []
#    2240 if labels is None:
# -> 2241     labels_out = ax.get_xticklabels(minor=minor)
#    2242     for l in labels_out:
#    2243         l._internal_update(kwargs)
#
# ...
